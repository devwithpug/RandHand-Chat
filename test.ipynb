# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np 


ax = plt.axes(projection='3d')

x1=np.array([0.7293073534965515, 0.7912315130233765, 0.7517409324645996, 0.7084354162216187])
y1=np.array([0.7295104265213013, 0.6195395588874817, 0.48991531133651733, 0.4027964174747467])
z1=np.array([-0.00022265914594754577, -0.13425704836845398, -0.23953229188919067, -0.3238430619239807])

x2=np.array([0.7012627124786377, 0.6851769089698792, 0.6063401699066162, 0.5267906785011292])
y2=np.array([0.6804540753364563, 0.584871232509613, 0.49643993377685547, 0.43391871452331543])
z2=np.array([-5.9780918491014745e-06, -0.11920376867055893, -0.18239958584308624, -0.2223159372806549])

ax.plot(x1, y1, z1, alpha=0.6, marker='o')
ax.plot(x2, y2, z2, alpha=0.6, marker='o')
plt.show()

print('x1-x2:',x1-x2)
print('z1-z2:',y1-y2)
print('z1-z2:',z1-z2)
# Out:
# x1-x2: [0.02804464 0.1060546  0.14540076 0.18164474]
# z1-z2: [ 0.04905635  0.03466833 -0.00652462 -0.0311223 ]
# z1-z2: [-0.00021668 -0.01505328 -0.05713271 -0.10152712]
